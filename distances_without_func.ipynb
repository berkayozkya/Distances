# %%
from math import*

# %% [markdown]
# #Vektör

# %%
u = [] 
n = int(input("N= ")) 
for i in range(n): 
    new_element = int(input())
    u.append(new_element)    
print("U =",u)

v = [] 
n = int(input("N= ")) 
for i in range(n): 
    new_element = int(input())
    v.append(new_element)    
print("V =",v)
# Out:
# N= 2
# 3
# 5
# U = [3, 5]
# N= 2
# 5
# 2
# V = [5, 2]

# %% [markdown]
# # Euclidean Distance
#  ![1_J2bK-UKhrW1Ill5EyAxXOQ.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)

# %%
def Euclidean_Distance(u,v):
  distance=0
  for i,j in zip(u,v):
    distance += ((i-j)**2)
  return sqrt(distance)
print("U= ",u,"\nV= ",v,"\nEuclidean Distance(U,V)= ",Euclidean_Distance(u,v))
# Out:
# U=  [3, 4]
# V=  [2, 2]
# Euclidean Distance(U,V)=  2.23606797749979

# %% [markdown]
# # Cosine Similarity
# ![image.png](data:image/png;base64,...)

# %%
def Dot_Product(u,v):
  Dot_Product=0
  for (i, j) in zip(u, v):
    Dot_Product += (i*j)
  return Dot_Product
print("Dot Product(U,V)= ",Dot_Product(u,v))


def Vector_Magnitude(m):
  Vector_Magnitude=0
  for i in m:
    Vector_Magnitude += (i**2)
  return sqrt(Vector_Magnitude)
print("||U||= ",Vector_Magnitude(u))
print("||V||= ",Vector_Magnitude(v))


def Cosine_Similarity(u,v):
  Cosine_Similarity = ((Dot_Product(u,v)) / Vector_Magnitude(u) * Vector_Magnitude(v))
  return Cosine_Similarity
print("U= ",u,"\nV= ",v,"\nCosine Similarity(U,V)= ",Cosine_Similarity(u,v))
# Out:
# Dot Product(U,V)=  14
# ||U||=  5.0
# ||V||=  2.8284271247461903
# U=  [3, 4]
# V=  [2, 2]
# Cosine Similarity(U,V)=  7.919595949289333

# %% [markdown]
# # Correlation
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Manhattan Distance
# ![image.png](data:image/png;base64,...)

# %%
def Manhattan_Distance(u,v):
  distance=0
  for i,j in zip(u,v):
    distance += abs(i-j)
  return distance
print("U= ",u,"\nV= ",v,"\nManhattan Distance(U,V)= ",Manhattan_Distance(u,v))
# Out:
# U=  [3, 5]
# V=  [5, 2]
# Manhattan Distance(U,V)=  5

# %% [markdown]
# # Minkowski
# ![image.png](data:image/png;base64,...)

# %%
p = int(input("P= "))
def Minkowski_Distance(u,v,p): 
  distance=0
  for i,j in zip(u,v):
    distance += (abs(i-j)**p)
  return distance**(1/p)
print("U= ",u,"\nV= ",v,"\nMinkowski_Distance(U,V)= ",Minkowski_Distance(u,v,p))
# Out:
# P= 2
# U=  [1, 2, 3, 4]
# V=  [4, 3, 2, 1]
# Minkowski_Distance(U,V)=  4.47213595499958

# %% [markdown]
# # Hamming Distance
# ![image.png](data:image/png;base64,...)

# %%
def hamming_distance(a,b):
    return sum(abs(e1-e2) for e1, e2 in zip(a,b)) 
liste1 = [0,0,0,0,0,1]
liste2 = [0,0,0,0,1,0]

dist = hamming_distance(liste1, liste2)
print(dist)
# Out:
# 2
